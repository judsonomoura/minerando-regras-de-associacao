# %% [markdown]
# # Gerando regras de associação com o A-Priori
#
# Bibliotecas necessárias:

# %%
import numpy as np
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv("./CE.csv")

# %%
df.head(5)
# Out:
#   NT_GER QE_I01 QE_I02 QE_I03 QE_I04 QE_I05 QE_I06 QE_I07 QE_I08 QE_I09  \
# 0  25_50   Q01A   Q02A   Q03A   Q04E   Q05E   Q06D   Q07B   Q08C   Q09C
# 1  25_50   Q01B   Q02A   Q03A   Q04D   Q05D   Q06B   Q07F   Q08C   Q09D
# 2  25_50   Q01A   Q02B   Q03A   Q04D   Q05D   Q06B   Q07E   Q08B   Q09B
# 3  50_75   Q01A   Q02D   Q03A   Q04D   Q05C   Q06B   Q07D   Q08C   Q09B
# 4  25_50   Q01B   Q02A   Q03A   Q04D   Q05E   Q06C   Q07B   Q08D   Q09D
#
#    ...   QE_I17 QE_I18 QE_I19 QE_I20 QE_I21 QE_I22 QE_I23 QE_I24 QE_I25 QE_I26
# 0  ...     Q17B   Q18A   Q19B   Q20A   Q21A   Q22C   Q23C   Q24E   Q25E   Q26F
# 1  ...     Q17E   Q18A   Q19B   Q20A   Q21A   Q22D   Q23B   Q24E   Q25E   Q26A
# 2  ...     Q17A   Q18A   Q19C   Q20D   Q21A   Q22B   Q23C   Q24E   Q25E   Q26A
# 3  ...     Q17A   Q18A   Q19B   Q20A   Q21A   Q22C   Q23C   Q24E   Q25H   Q26A
# 4  ...     Q17B   Q18A   Q19C   Q20G   Q21A   Q22C   Q23D   Q24E   Q25E   Q26F
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Passo preliminar: transformar os dados em itemsets (formato de entrada do algoritmo).

# %%
te = TransactionEncoder()
te_ary = te.fit(df.values).transform(df.values)
df_ = pd.DataFrame(te_ary, columns=te.columns_)

# %%
df_.head(5)
# Out:
#     0_25  25_50  50_75  75_100   Q01A   Q01B   Q01C   Q01D   Q01E   Q02A  \
# 0  False   True  False   False   True  False  False  False  False   True
# 1  False   True  False   False  False   True  False  False  False   True
# 2  False   True  False   False   True  False  False  False  False  False
# 3  False  False   True   False   True  False  False  False  False  False
# 4  False   True  False   False  False   True  False  False  False   True
#
#     ...    Q_1633  Q_1635  Q_1641  Q_1642  Q_1643  Q_1650  Q_1651  Q_1652  \
# 0   ...     False   False   False   False   False   False   False   False
# 1   ...     False   False   False   False   False   False   False   False
# 2   ...     False   False   False   False   False   False   False   False
# 3   ...     False   False   False   False   False   False   False   False
# 4   ...     False   False   False   False   False   False   False   False
#
#    Q_1653  Q_1699
# 0   False   False
# 1   False   False
# 2   False   False
# 3   False   False
# 4   False   False
#
# [5 rows x 188 columns]

# %% [markdown]
# # O procedimento de geração de regras de associação é basicamente realizado em dois passos.
#
# #### 1° passo: descobrir os itemsets frequentes.

# %%
frequent_itemsets = apriori(df_, min_support=0.4, use_colnames=True)

# %% [markdown]
# #### 2° passo: descobrir as regras de associação

# %%
rules = association_rules(frequent_itemsets, metric='lift')

# %%
rules.head(6)
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0      (Q01A)     (25_50)            0.773635            0.569241  0.429721
# 1     (25_50)      (Q01A)            0.569241            0.773635  0.429721
# 2     (25_50)      (Q03A)            0.569241            0.986506  0.560159
# 3      (Q03A)     (25_50)            0.986506            0.569241  0.560159
# 4     (25_50)      (Q12A)            0.569241            0.871205  0.497016
# 5      (Q12A)     (25_50)            0.871205            0.569241  0.497016
#
#    confidence      lift  leverage  conviction
# 0    0.555456  0.975783 -0.010665    0.968990
# 1    0.754900  0.975783 -0.010665    0.923562
# 2    0.984045  0.997505 -0.001401    0.845730
# 3    0.567821  0.997505 -0.001401    0.996714
# 4    0.873120  1.002198  0.001090    1.015090
# 5    0.570492  1.002198  0.001090    1.002913

# %%
asc_rules = rules[['antecedents', 'consequents', 'confidence', 'lift']]

# %%
asc_rules.tail(5)
# Out:
#       antecedents                             consequents  confidence  \
# 16193      (Q24E)  (Q18A, Q14A, Q15A, Q03A, Q12A, Q_1623)    0.632210
# 16194      (Q15A)  (Q18A, Q14A, Q24E, Q03A, Q12A, Q_1623)    0.491253
# 16195      (Q03A)  (Q18A, Q14A, Q15A, Q24E, Q12A, Q_1623)    0.416133
# 16196      (Q12A)  (Q18A, Q14A, Q15A, Q24E, Q03A, Q_1623)    0.471207
# 16197    (Q_1623)    (Q18A, Q14A, Q15A, Q24E, Q03A, Q12A)    0.427760
#
#            lift
# 16193  1.049086
# 16194  1.052517
# 16195  1.003738
# 16196  1.037643
# 16197  1.006787

# %% [markdown]
# #### Filtro para pegar as regras que envolvem rendimento

# %%
notas = set(np.unique(df['NT_GER']))

# %%
df_new = pd.DataFrame()

for i in range(len(asc_rules)):
    if notas.intersection(asc_rules['consequents'][i]):
        df_new[i] = asc_rules.loc[i]

df_new = df_new.transpose()

# %% [markdown]
# #### Regras Geradas

# %%
df_new
# Out:
#                       antecedents                        consequents  \
# 0                          (Q01A)                            (25_50)
# 3                          (Q03A)                            (25_50)
# 5                          (Q12A)                            (25_50)
# 6                          (Q14A)                            (25_50)
# 9                          (Q15A)                            (25_50)
# 11                         (Q18A)                            (25_50)
# 12                       (Q_1623)                            (25_50)
# 201                  (Q01A, Q03A)                            (25_50)
# 203                        (Q01A)                      (25_50, Q03A)
# 205                        (Q03A)                      (Q01A, 25_50)
# 206                  (Q14A, Q01A)                            (25_50)
# 209                        (Q14A)                      (Q01A, 25_50)
# 210                        (Q01A)                      (Q14A, 25_50)
# 212                (Q_1623, Q01A)                            (25_50)
# 215                      (Q_1623)                      (Q01A, 25_50)
# 216                        (Q01A)                    (Q_1623, 25_50)
# 220                  (Q03A, Q12A)                            (25_50)
# 222                        (Q03A)                      (25_50, Q12A)
# 223                        (Q12A)                      (25_50, Q03A)
# 225                  (Q14A, Q03A)                            (25_50)
# 227                        (Q14A)                      (25_50, Q03A)
# 229                        (Q03A)                      (Q14A, 25_50)
# 232                  (Q15A, Q03A)                            (25_50)
# 234                        (Q15A)                      (25_50, Q03A)
# 235                        (Q03A)                      (25_50, Q15A)
# 238                  (Q18A, Q03A)                            (25_50)
# 240                        (Q03A)                      (25_50, Q18A)
# 241                        (Q18A)                      (25_50, Q03A)
# 243                (Q_1623, Q03A)                            (25_50)
# 245                      (Q_1623)                      (25_50, Q03A)
# ...                           ...                                ...
# 11160    (Q14A, Q03A, Q18A, Q12A)                    (Q_1623, 25_50)
# 11161  (Q14A, Q_1623, Q03A, Q18A)                      (25_50, Q12A)
# 11163  (Q14A, Q_1623, Q18A, Q12A)                      (25_50, Q03A)
# 11166  (Q_1623, Q03A, Q18A, Q12A)                      (Q14A, 25_50)
# 11170  (Q14A, Q_1623, Q03A, Q12A)                      (25_50, Q18A)
# 11175          (Q14A, Q03A, Q18A)              (Q_1623, 25_50, Q12A)
# 11176          (Q14A, Q18A, Q12A)              (Q_1623, 25_50, Q03A)
# 11177        (Q14A, Q_1623, Q18A)                (25_50, Q03A, Q12A)
# 11179          (Q03A, Q18A, Q12A)              (Q14A, Q_1623, 25_50)
# 11180        (Q_1623, Q03A, Q18A)                (Q14A, 25_50, Q12A)
# 11182        (Q_1623, Q18A, Q12A)                (Q14A, 25_50, Q03A)
# 11185          (Q14A, Q03A, Q12A)              (Q_1623, 25_50, Q18A)
# 11186        (Q14A, Q_1623, Q03A)                (25_50, Q18A, Q12A)
# 11188        (Q14A, Q_1623, Q12A)                (25_50, Q03A, Q18A)
# 11191        (Q_1623, Q03A, Q12A)                (Q14A, 25_50, Q18A)
# 11195                (Q14A, Q18A)        (Q_1623, 25_50, Q03A, Q12A)
# 11196                (Q03A, Q18A)        (Q14A, Q_1623, 25_50, Q12A)
# 11197                (Q18A, Q12A)        (Q14A, Q_1623, 25_50, Q03A)
# 11198              (Q_1623, Q18A)          (Q14A, 25_50, Q03A, Q12A)
# 11200                (Q14A, Q03A)        (Q_1623, 25_50, Q18A, Q12A)
# 11201                (Q14A, Q12A)        (Q_1623, 25_50, Q03A, Q18A)
# 11202              (Q14A, Q_1623)          (25_50, Q03A, Q18A, Q12A)
# 11204                (Q03A, Q12A)        (Q14A, Q_1623, 25_50, Q18A)
# 11205              (Q_1623, Q03A)          (Q14A, 25_50, Q18A, Q12A)
# 11207              (Q_1623, Q12A)          (Q14A, 25_50, Q03A, Q18A)
# 11210                      (Q18A)  (Q14A, Q03A, Q12A, Q_1623, 25_50)
# 11211                      (Q14A)  (Q18A, Q03A, Q12A, Q_1623, 25_50)
# 11212                      (Q03A)  (Q18A, Q14A, Q12A, Q_1623, 25_50)
# 11213                      (Q12A)  (Q18A, Q14A, Q03A, Q_1623, 25_50)
# 11214                    (Q_1623)    (Q18A, Q14A, Q03A, Q12A, 25_50)
#
#       confidence      lift
# 0       0.555456  0.975783
# 3       0.567821  0.997505
# 5       0.570492    1.0022
# 6       0.582911   1.02401
# 9       0.567747  0.997374
# 11      0.567568   0.99706
# 12      0.569806   1.00099
# 201     0.553626  0.972568
# 203     0.545394   0.97364
# 205     0.427707  0.995314
# 206     0.572015   1.00487
# 209     0.435871   1.01431
# 210     0.529293  0.966539
# 212     0.555336  0.975572
# 215     0.431005   1.00299
# 216      0.53466  0.977729
# 220     0.569049  0.999661
# 222      0.49715   1.00027
# 223     0.562947   1.00498
# 225     0.581474   1.02149
# 227     0.573336   1.02352
# 229     0.545989  0.997026
# 232     0.566419  0.995042
# 234     0.560087  0.999871
# 235     0.474441         1
# 238     0.566634  0.995419
# 240     0.503288   1.00026
# 241     0.560055  0.999813
# 243     0.568827  0.999273
# 245     0.563137   1.00532
# ...          ...       ...
# 11160   0.563102   1.02974
# 11161    0.51048   1.02709
# 11163   0.576928   1.02994
# 11166   0.544544  0.994389
# 11170   0.519671   1.03282
# 11175   0.493718    1.0303
# 11176   0.557463    1.0315
# 11177   0.505568   1.03084
# 11179   0.525984  0.998999
# 11180   0.477533  0.998689
# 11182   0.539331   1.00132
# 11185   0.500053   1.02995
# 11186   0.453189   1.02812
# 11188   0.513959   1.03517
# 11191   0.487795   1.00992
# 11195   0.487795   1.03116
# 11196   0.461599   1.00104
# 11197   0.520945    1.0016
# 11198   0.473136   1.00329
# 11200   0.436642   1.02373
# 11201   0.494449   1.02923
# 11202   0.448451   1.02929
# 11204   0.469289   1.00583
# 11205    0.42571   1.00668
# 11207   0.482659   1.01308
# 11210    0.45624   1.00277
# 11211   0.430531   1.02121
# 11212   0.409996   1.00147
# 11213   0.464257   1.00605
# 11214   0.421451   1.00878
#
# [389 rows x 4 columns]
