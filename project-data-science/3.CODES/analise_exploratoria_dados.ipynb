# %%
import pandas as pd

# %%
df = pd.read_csv('./2.DADOS/MICRODADOS_ENADE_2017.txt', sep=';')
# Out:
# /home/dieinison/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (29,31,32,44,45,46,47,54,55,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(10)
# Out:
#    NU_ANO  CO_IES  CO_CATEGAD  CO_ORGACAD  CO_GRUPO  CO_CURSO  CO_MODALIDADE  \
# 0    2017       1           1       10028      5710         3              1
# 1    2017       1           1       10028      5710         3              1
# 2    2017       1           1       10028      5710         3              1
# 3    2017       1           1       10028      5710         3              1
# 4    2017       1           1       10028      5710         3              1
# 5    2017       1           1       10028      5710         3              1
# 6    2017       1           1       10028      5710         3              1
# 7    2017       1           1       10028      5710         3              1
# 8    2017       1           1       10028      5710         3              1
# 9    2017       1           1       10028      5710         3              1
#
#    CO_MUNIC_CURSO  CO_UF_CURSO  CO_REGIAO_CURSO   ...    QE_I72 QE_I73  \
# ...

# %%
len(df)
# Out:
# 537436
